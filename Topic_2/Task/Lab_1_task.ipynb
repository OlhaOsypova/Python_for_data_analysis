# %% [markdown]
# # Завдання ЛР 1
#
# ### Завдання 1
# Перейдіть за посиланням https://www.markdowntutorial.com/. В своєму ноутбуці виконайте завдання перших трьох пунктів цього туторіалу (пункт 1 - Italics and Bold, пункт 2 - Headers, пункт 3 - Links)
#
# ### Завдання 2
# **Необхідно:**
# 1. Зчитати файл "Data_IE_301.xlsx", НОМЕР ЛИСТА ВІДПОВІДАЄ ПОРЯДКОВОМУ НОМЕРУ СТУДЕНТА У ЗАГАЛЬНОМУ СПИСКУ ГРУПИ
# 2. Виконати попередню підготовку даних (видалити порожні стовпчики; заповнити пропущені значення/видалити рядки, в яких більшість значень є пропущеними)
# 3. Перейменувати стовпці таблиці на Column_1, Column_2 і т.д.
# 4. Видалити перших три рядки
# 5. Вивести на екран перші 7 значень 1, 3 та 5 стовпчиків, використовуючи і метод .loc, і метод .iloc
# 6. Вивести на екран будь-які 30 значень з 2-го по 6-й стовпчики
# 7. Вивести на екран зріз, що містить значення 2-го, 25-го та 50-го рядків для стовпчиків Column_1, Column_4
# 8. Записати таблицю в файл excel або csv
#
# ### Завдання 3
# #### Чому працівники залишають компанію?
# Ви працюєте в HR відділі великої компанії. Правління стурбоване відносно високою плинністю кадрів, і ваша команда повинна шукати шляхи зменшення кількості працівників, які залишають компанію. Команда повинна краще розуміти ситуацію, які співробітники, швидше за все, підуть і чому. Коли стане ясно, які фактори впливають на відтік співробітників, ви можете представити свої висновки разом із своїми ідеями щодо того, як зменшити плинність кадрів.
#
#
# **Дані щодо працівників усіх відділів розміщено в файлі employers.csv**
#
# - department - відділ, до якого належить співробітник.
# - promoted - 1, якщо працівник отримав підвищення за попередні 24 місяці, 0 в іншому випадку.
# - review — зведена оцінка, яку працівник отримав під час останнього інтерв'ю з керівником відділу.
# - projects – у скількох проєктах бере участь співробітник.
# - salary - з міркувань конфіденційності зарплата представлена трьома рівнями: низька, середня, висока.
# - tenure - скільки років працівник працює в компанії.
# - satisfaction - оцінка задоволеності співробітників роботою в компанії.
# - bonus - 1, якщо працівник отримував премію за попередні 24 місяці, 0 в іншому випадку.
# - avg_hrs_month - середня кількість годин, відпрацьованих працівником за місяць.
# - left - "yes", якщо співробітник залишив компанію, "no" в протидежному випадку.

# %% [markdown]
# **Необхідно:**
# 1. Відкрити файл з початковими даними
# 2. Відобразити ромір датафрейму, тип даних та кількість пропущених значень для кожної колонки датафрейму
# 3. У разі наявності видалити зайві стовпчики, видалити або заповнити пропуски в даних
# 4. Вивести описову статистику для кількісних показників. Для одного обраного вами кількісного показника робити висновки за результатами наведеної описової статистики.
# 5. Вивести описову статистику для категоріальних показників. Для одного обраного вами категоріального показника робити висновки за результатами наведеної описової статистики.
# 6. Визначити скільки працівників залишилося в компанії, а скільки - звільнилося.
# 7. Відібрати працівників, які нещодавно отримали підвищення, але все одно залишили компанію. Чи багато таких працівників?
# 8. Чи багато працівників, що мають високий рівень зарплати, вирішили залишити компанію.
# 9. Після виконання всіх завдань збережіть датафрейм в файл csv
