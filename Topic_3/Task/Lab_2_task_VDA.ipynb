# %% [markdown]
# # Лабораторна робота 2
# ### Візуальний аналіз даних
# ### 5 балів

# %% [markdown]
# ## Частина 1
# ### <span style="color:red">Візуалізація за допомогою бібліотеки Pandas</span>
# **Необхідно:**
# 1. Відкрити файл із початковими даними, який ви отримали в результаті виконання Лабораторної роботи 1
# 2. Візуалізуйте розподіл показників review та satisfaction для кожного відділу компанії. Зробіть короткі висновки
# 3. Візуалізуйте скільки працівників компанії отримали підвищення протягом 24 місяців та скільки працівників компанії отримали премію протягом 24 місяців.  Зробіть короткі висновки
# 4. Візуалізуйте взаємозв'язок між показниками satisfaction та avg_hrs_month. Зробіть короткі висновки
# 5. Візуалізуйте кількість працівників в кожному відділі компанії.

# %% [markdown]
# ## Частина 2
# ### <span style="color:red"> Візуалізація за допомогою бібліотеки Seaborn</span>
# В датафреймі cities міститься набір показників, що характеризують комфортність проживання в 266 містах світу. Інформація подана у вигляді індексів, де 1 - найменш комфортний варіант, 10 - найбільш комфортний варіант (наприклад, в стовпчику Cost of living "1" відповідає найдорожчим для проживання містам, "10" - найдешевшим).
# ### Завдання
# 1. Зобразити на графіку кількість країн по кожному континенту
# 2. Візуалізувати розподіл показника Startups, зробити короткі висновки
# 3. Візуалізувати розподіл показника Internet Access по континентах, зробити короткі висновки
# 4. За допомогою візуалізацій дослідити характер взаємозв'язку між показниками Economy та Education, зробити короткі висновки
# 5. Визначити 3 показника, які настісніше корелюють із показником Healthcare
# 6. Оберіть кілька показників, які, на вашу думку, характеризують легкість ведення бізнесу та за допомогою візуалізацій проаналізуйте легкість ведення бізнесу на кожному континенті, відповідь обгрунтуйте
# 7. Створіть новий датафрейм, до якого входитимуть тільки міста США, Великобританії, Канади та Франції. Стовпчиками нового датафрейму оберіть кілька показників, які, на вашу думку, характеризують туристичну привабливість міста.
# 8. За допомогою візуалізацій зробіть порівняльний аналіз туристичної привабливості 4 країн (США, Великобританія, Канада та Франція).
# ## Будь-ласка, не забувайте робити короткі висновки після кожного пункту

# %%
import pandas as pd
cities = pd.read_csv('cities.csv', skipinitialspace=True)
cities.head()
