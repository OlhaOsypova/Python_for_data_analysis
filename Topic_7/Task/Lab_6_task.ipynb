# %% [markdown]
# ## Лабораторна робота 6
#
# Дані для проведення лабораторної роботи 6 зібрано тут:
# #### [Штучний інтелект на світовій арені: домінуючі гравці та їх майбутні конкуренти](https://intersog.com/blog/ai-dominant-players-and-aspiring-challengers/)
#
# **Глобальний індекс штучного інтелекту (GAII)** — це показник, створений Tortoise Media для ранжування країн на основі потенціалу штучного інтелекту, зокрема шляхом вимірювання рівнів інвестицій, інновацій та впровадження.
# Датасет містить сім індикаторів, що формують GAII для 61 країн, а також загальну інформацію про країни (регіон, група доходу та політичний режим).
# ### Опис датасету
# - Country - назва країни
# - Talent - індикатор характеризує наявність кваліфікованих практиків в сфері штучного інтелекту
# - Infrastructure - індикатор інфраструктури зосереджується на надійності та масштабності інфраструктури (від електрики та Інтернету до надпотужних коп'ютерів)
# - Operating Environment -  індикатор зосереджується на нормативному контексті та громадській думці щодо штучного інтелекту  - Research - індикатор фокусується на масштабі спеціалізованих досліджень в сфері штучного інтелекту
# - Development - індикатор фокусується на розробці фундаментальних платформ і алгоритмів, на яких спираються інноваційні проєкти штучного інтелекту
# - Government Strategy - індикатор характеризує ступінь прихильності національного уряду штучному інтелекту
# - Commercial -    індикатор фокусується на рівні активності стартапів, інвестицій та бізнес-ініціатив на основі штучного інтелекту
# - Total score - Глобальний індекс штучного інтелекту
# - Region, Income group, Political regime - регіон, група доходу та політичний режим

# %%
import pandas as pd
df = pd.read_csv('AI_index.csv')
df.head()
# Out:
#                     Country  Talent  Infrastructure  Operating Environment  \
# 0  United States of America  100.00           94.02                  64.56
# 1                     China   16.51          100.00                  91.57
# 2            United Kingdom   39.65           71.43                  74.65
# 3                    Canada   31.28           77.05                  93.94
# 4                    Israel   35.76           67.58                  82.44
#
#    Research  Development  Government Strategy  Commercial  Total score  \
# 0    100.00       100.00                77.39      100.00       100.00
# 1     71.42        79.97                94.87       44.02        62.92
# 2     36.50        25.03                82.82       18.91        40.93
# 3     30.67        25.78               100.00       14.88        40.19
# 4     32.63        27.96                43.91       27.33        39.89
#
#          Region  Income group   Political regime
# ...

# %% [markdown]
# ### Завдання
# 1. Провести розвідковий та візуальний аналіз даних:
# - Як різні регіони світу розподіляються за середніми значеннями індикаторів Research, Development, Government Strategy та Commercial? Чи можна виявити спільні тенденції в їх розвитку?
# - Чи існує зв'язок між рівнем доходу країни та розвинутістю інфраструктури ШІ? Чи можна встановити взаємозв'язок між групою доходу країни та рівнем Talent, Infrastructure та Operating Environment?
# - Чи спостерігається кореляція між рівнем розвитку країни та її індексом ШІ?
# - Чи існують відмінності у рівні наукових досліджень та розробок між країнами з різним політичним режимом? Як відрізняється активність у сфері штучного інтелекту в демократичних та авторитарних режимах?
# - Як розподіляються країни за регіонами в залежності від їх індексу ШІ? Чи можна виявити регіони, які вже відзначаються високим рівнем активності у сфері штучного інтелекту?
#   <span style="color:red"> *Далі для кластерного аналізу використовуються лише кількісні показники. Категоріальні змінні слід виключити*</span>
# 2. Виконати ієрархічний кластерний аналіз, зробити припущення про можливу кількість кластерів.
# 3. Застосувати метод головних компонент (PCA) для зниження розмірності даних:
# - обґрунтувати вибір кількості компонент (наприклад, за допомогою графіка "накопиченої дисперсії");
# - дати інтерпретацію змісту отриманих головних компонент.
# 4. Виконати кластеризацію за методом к-середніх, використовуючи у якості вхідних даних отримані значення головних компонент. Кількість кластерів обрати за методом "зігнутого ліктя"
# 5. **Дати детальну економічну характеристику отриманим кластерам. Які країни формують кожен кластер?**
