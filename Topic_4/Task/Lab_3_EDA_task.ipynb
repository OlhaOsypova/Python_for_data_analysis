# %% [markdown]
# Датафрейм містить результати опитування українських ІТ-спеціалістів влітку 2022 року (опитування проводилося на сайті популярної спільноти програмістів https://dou.ua/ )

# %% [markdown]
# ## Завдання
#
# **1. Перегляньте основну інформацію про датафрейм:**
# - Загальну структуру даних (розмір датафрейму, типи даних).
# - Виведіть на екран перші декілька рядків для отримання загального уявлення про дані.
#
# **2. Попередня обробка даних:**
# - Визначте, які стовпці можуть бути непотрібними для подальшого аналізу (наприклад, ідентифікатори, неінформативні дані) та видаліть зайві стовпчики.
# - Видаліть викиди (нетипові/аномальні/помилково введені дані). <span style="color:red"> **Для кількісних показників в даній ЛР вам необхідно самостійно розібрати та використати один із двох  методів за вашим вибором для детекції та видалення викидів: Z-Scores та Interquartile Range** </span>
#
# **3. Заповніть/видаліть пропуски в даних:**
# - Виявіть пропущені значення в даних.
# - Заповніть пропуски, використовуючи методи, які на вашу думку, є оптимальними для досліджуваного набору даних.
# - Деякі спостереження можна видалити.
#
# **4. Дослідіть, як змінилося життя українських ІТ-спеціалістів з початком повномасштабної війни в Україні?**
#
# **5. Як можна охарактеризувати "типового ІТ-спеціаліста" в Україні у 2022 році?**
# - Проведіть аналіз для визначення основних характеристик "типового ІТ-спеціаліста" в Україні у 2022 році, включаючи вік, стать, освіту, досвід роботи та інші фактори.
#
# **6. Як ІТ-спеціалісти оцінюють свій поточний рівень фінансового забезпечення?**
# - Аналіз відповідей щодо фінансового стану ІТ-спеціалістів.
# - Виявлення рівня задоволеності заробітною платою та можливість зростання.
#
# **7. Детально охаратеризуйте освітній рівень та професійні навички дата саєнтістів та дата аналітиків**
# - Аналіз даних щодо освіти (рівень освіти, спеціалізація).
# - Виявлення основних професійних навичок, що вимагаються для позицій дата саєнтістів та дата аналітиків.
#
#  ### <span style="color:red"> До завдань 2-7 обов'язково мають бути пояснення ходу виконання завдань (не коментування коду, а саме хід ваших думок), опис отриманих результатів та висновки</span>

# %%
import pandas as pd
survey = pd.read_csv('portrait_2022.csv')
survey.head()
